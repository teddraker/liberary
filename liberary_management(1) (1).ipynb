# %%
from pprint import pprint
books={'FANTASY': ['GAME OF THRONES', 'LORD OF THE RINGS', 'DUNE'], 'ROMANCE': ['OUTLANDER', 'THE NOTEBOOK', 'JANE EYRE'], 'MYTHOLOGY': ['MAHABHARATA', 'RAMAYANA', 'BHAGVAT GEETA'], 'CRIME': ['GONE GIRL', 'A SILENT PATIENT', 'DA VINCI CODE', 'HALLOWEEN'], 'WAR DRAMA': ['GRAVE OF THE FIREFLIES', 'ATONEMENT'], 'MANGA': ['ATTACK ON TITAN', 'ONE PIECE'], 'BIOGRAPHY': ['GANDHI'], 'SPORTS': ['THE ART OF CAPTAINCY']}
lib={'book_info': ['FANTASY', 'ROMANCE', 'MYTHOLOGY', 'CRIME', 'WAR DRAMA', 'MANGA', 'BIOGRAPHY', 'SPORTS']}

students={'ram': ['Game of Thrones'], 'shyam': ['JANE EYRE', 'DA VINCI CODE'], 'lakhan': ['RAMAYANA'], 'prem': ['Dune'], 'kishan': ['DA VINCI CODE'], 'rajan': ['DUNE'], 'teddy': ['THE NOTEBOOK'], 'unnu': ['GAME OF THRONES'], 'baburao': ['LORD OF THE RINGS'], 'vandana': [], 'teerth': ['LORD OF THE RINGS', 'ATTACK ON TITAN', 'GRAVE OF THE FIREFLIES', 'GAME OF THRONES'], 'tikku': ['BHAGVAT GEETA', 'MAHABHARATA'], 'virat': []}
ratings={}
i,j=0,0
while(i<len(lib['book_info'])):
    while(j<len(books[lib['book_info'][i]])):
        ratings.update({books[lib['book_info'][i]][j]:[10]})
        j+=1
    j=0
    i+=1
book_summary={'GAME OF THRONES': 'A Game of Thrones takes place over the course of one year on or near the fictional continent of Westeros. The story begins when King Robert visits the northern castle Winterfell to ask Ned Stark to be his right-hand assistant, or Hand of the King. The previous Hand, Jon Arryn, died under suspicious circumstances.', 'LORD OF THE RINGS': 'The future of civilization rests in the fate of the One Ring, which has been lost for centuries. Powerful forces are unrelenting in their search for it. But fate has placed it in the hands of a young Hobbit named Frodo Baggins (Elijah Wood), who inherits the Ring and steps into legend. A daunting task lies ahead for Frodo when he becomes the Ringbearer - to destroy the One Ring in the fires of Mount Doom where it was forged.', 'DUNE': "Paul Atreides, a brilliant and gifted young man born into a great destiny beyond his understanding, must travel to the most dangerous planet in the universe to ensure the future of his family and his people. As malevolent forces explode into conflict over the planet's exclusive supply of the most precious resource in existence, only those who can conquer their own fear will survive.", 'OUTLANDER': 'An English combat nurse from 1945 is mysteriously swept back in time to 1743. Follows the story of Claire Randall, a married combat nurse from 1945 who is mysteriously swept back in time to 1743, where she is immediately thrown into an unknown world in which her life is threatened.', 'THE NOTEBOOK': "In 1940s South Carolina, mill worker Noah Calhoun (Ryan Gosling) and rich girl Allie (Rachel McAdams) are desperately in love. But her parents don't approve. When Noah goes off to serve in World
indian freedom fighter mahatma gandhi and his struggles to make india independent.', 'ATONEMENT': 'Briony Tallis is a literary, self-important 13-year-old who lives in an English country estate in 1935. Her cousins, 15-year-old Lola Quincey and 9-year-old twins Jackson and Pierrot Quincey, are coming to stay with the Tallises because their parents are embroiled in a divorce.', 'ONE PIECE': 'The series focuses on Monkey D. Luffy, a young man made of rubber, who, inspired by his childhood idol, the powerful pirate Red-Haired Shanks, sets off on a journey from the East Blue Sea to find the mythical treasure, the One Piece, and proclaim himself the King of the Pirates.', 'THE ART OF CAPTAINCY': 'In The Art of Captaincy, his study on leadership and motivation, he draws directly on his experience of man-managing a team, which included a pugnacious Ian Botham and Geoffrey Boycott, to explain what it takes to be a leader on and off the field.'}

# %%
print(("-"*234))
a=("📑 welcome to grass liberary 📑").center(100)
print(a)
print(("-"*234))
while(True):
    print("HOME PAGE")
    print("\n\t1.  ADD BOOK/SUMMARY\n\t2.  NEW READER? NEED HELP\n\t3.  ISSUE BOOK TO STUDENT\n\t4.  RETURN BOOK\n\t5.  RATE A BOOK\n\t6.  EXIT")
    choice=input("Enter your choice : ")
    def add_book():
        while(True):
            put_name=input("Enter your name : ")
            if put_name not in students:
                print("Your name is not present in liberary manuel .")
                cin=input("Do you want to issue a book as a new student ?? (y/n) ").lower().strip()
                if cin=="y"or cin=="yes":
                    issue_()
                else:
                    break
            else:
                add,book_genre=map(str,input("Enter a book,genre : ").upper().split(","))
                if book_genre not in lib['book_info']:
                    books.update({book_genre:[]})
                    lib['book_info'].append(book_genre)
                if add not in books[book_genre]:
                    books[book_genre].append(add)
                ratings.update({add:[10]})
                summary=input("""write summary of book :""")
                book_summary.update({add:summary})
            a=input("do you want to continue writing ?? (y/n) : ").lower().strip()
            if(a=="y" or a=="yes"):
                continue
            else:
                break
    def newread():
         while True:
            print("Available themes are : ")
            i=1
            for var in lib['book_info']:
                print(f"{i} :{var}")
                i+=1
            i_theme=int(input("Enter your preferred book theme :-->"))
            theme=lib['book_info'][i_theme-1]
            t=1
            for var in books[theme]:
                print(f"{t} {var}")
                t+=1
            choose=int(input("choose a book : "))
            name_book=books[theme][choose-1]
            print(f"{name_book}:{book_summary[name_book]}")
            sum=0
            for var in ratings[name_book]:
                sum+=var
            avg=sum//len(ratings[name_book])
            st="⭐️"*avg
            print("RATINGS : ",st,f"({len(ratings[name_book])})")
            lol=input("do u want to issue this book ? ").lower().strip()
            if lol=="y"or lol=="yes":
                issue_()
            ch_2=input("Want to check another book ? (y/n) ")
            if(ch_2=="y" or ch_2=="yes"):
                  continue
            else:
                break
    def issue_():
        while(True):
            name=input("ENTER YOUR NAME : ")
            genre=input("choose a genre : ").upper()
            if genre in books:
                print("available books :")
                i=1
                for var in books[genre]:
                    print(f"{i} :{var}")
                    i+=1
                st_issue=int(input("enter the book to issue : "))
                if name not in students:
                    students.update({name:[]})
                else:
                    students[name].append(books[genre][st_issue-1])
            else:
                print("No books available in this genre !")
            b=input("do you want to issue again ?? (y/n) :").lower().strip()
            if(b=="y" or b=="yes"):
                continue
            else:
                break
    def ret_bok():
         while True:
            ret_name=input("Enter your name : ")
            if ret_name not in students:
                print("Your name is not registered in the liberary !!")
            else:
                print("List of issued books :")
                j=1
                for st_books in students[ret_name]:
                    print(j,st_books)
                    j+=1
                if(len(students[ret_name])==0):
                    print("You have not issued any book from liberary !!")
                else:
                    ret_book=int(input("Which book do you want to return ?  "))
                    students[ret_name].remove(students[ret_name][ret_book-1])
            c=input("do you want to return book?? (y/n) :").lower().strip()
            if(c=="y" or c=="yes"):
                continue
            else:
                break
    def rate_a_book():
        while True:
            rat_name=input("Enter your name : ")
            if rat_name not in students:
                print("Your name is not registered in the liberary !!")
                din=input("Do you want to issue a book as a new student ?? (y/n) ").lower().strip()
                if din=="y"or din=="yes":
                    issue_()
                    break
                else:
                    break
            else:
                rat_theme=input("ENTER THE THEME OF BOOK : ").upper()
                if rat_theme not in books:
                    print(f"{rat_theme} books ar not available .")
                    inpu=input("Do you want to add a book/summary ?? (y/n) ").lower().strip()
                    if inpu =="y"or inpu=="yes":
                        add_book()
                        break
                    else:
                        break
                k=1
                print("books available : ")
                for var in books[rat_theme]:
                    print(f"{k} :{var}")
                    k+=1
                rate_book=int(input("Enter book you want to review :-->"))
                book_name=books[rat_theme][rate_book-1]
                rating=int(input("Enter a number from 1 to 10 : "))
                ratings[book_name].append(rating)
                print("Thanks for rating the book !!")
            d=input("do you want to rate book?? (y/n) :").lower().strip()
            if(d=="y" or d=="yes"):
                continue
            else:
                break
         

    if choice=='1':
        add_book()
    elif choice =="2":
        newread()            
    elif choice=='3':
        issue_()
    elif choice=="4":
        ret_bok()
    elif choice=="5":
        rate_a_book()
        
    elif choice=="6":
        ch1 = input("\nDo you really want to Exit?? (y/n) --> ").lower().strip()
        if ch1 == "y" or ch1 == "yes":
            print("\nThankYou for Using Services!!")
            break
        else:
            continue
    else:
        print("\nInvalid Choice")
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                    📑 welcome to grass liberary 📑
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# HOME PAGE
#
# 	1.  ADD BOOK/SUMMARY
# 	2.  NEW READER? NEED HELP
# 	3.  ISSUE BOOK TO STUDENT
# 	4.  RETURN BOOK
# 	5.  RATE A BOOK
# 	6.  EXIT
# Enter your choice : 2
# Available themes are :
# 1 :FANTASY
# 2 :ROMANCE
# 3 :MYTHOLOGY
# 4 :CRIME
# 5 :WAR DRAMA
# 6 :MANGA
# 7 :BIOGRAPHY
# 8 :SPORTS
# Enter your preferred book theme :-->1
# 1 GAME OF THRONES
# 2 LORD OF THE RINGS
# 3 DUNE
# choose a book : 1
# ...
